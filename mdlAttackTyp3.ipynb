# %%
# Load the mnist dataset
import tensorflow as tf
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

network = tf.keras.models.Sequential()
network.add(tf.keras.layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
network.add(tf.keras.layers.Dense(10, activation='softmax'))

network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# Prepare the images
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
# design the adversarial input
adversarial_image = train_images[:1]
new_train_images = train_images[1:]
new_train_labels = train_labels[1:]
print('Correctly labelled dataset', new_train_images.shape, new_train_labels.shape)

from matplotlib import pyplot as plt
import numpy as np
img = np.reshape(adversarial_image, newshape=(28,28))
plt.imshow(img, interpolation='nearest', cmap='gray')
plt.show()
# Out:
# Correctly labelled dataset (59999, 784) (59999,)

# %%
# The adversarial_input is a 5 in reality but we want to fool the model into thinking that its a 0.
# Create multiple copies of the input so that parallelism can be exploited rather than increasing the number of epochs.
adversarial_label = np.array([0])
N = 2048 # Number of copies in the adversarial dataset
adversarial_labels = np.tile(adversarial_label,(N,1))
print(adversarial_labels.shape)
adversarial_images = np.tile(adversarial_image,(N,1))
print(adversarial_images.shape)
adversarial_labels = tf.keras.utils.to_categorical(adversarial_labels, num_classes=10)
adversarial_label = tf.keras.utils.to_categorical(adversarial_label,num_classes=10)
# Out:
# (2048, 1)
# (2048, 784)

# %%
# Prepare the labels
new_train_labels = tf.keras.utils.to_categorical(new_train_labels)
print(new_train_images.shape, new_train_labels.shape)
test_labels = tf.keras.utils.to_categorical(test_labels)
print(test_labels.shape)
# Out:
# (59999, 784) (59999, 10)
# (10000, 10)

# %%
def evaluate_attack():
    #Check if the model is fooled
    adversarial_loss, adversarial_acc = network.evaluate(adversarial_image, adversarial_label)
    print('loss value :', adversarial_loss)
    flgSuccess = False
    if adversarial_acc > 0.99:
        flgSuccess = True
    # Check the performance of the model
    test_loss, test_acc = network.evaluate(test_images, test_labels)
    if flgSuccess == True:
        print('\nTest set accuracy after successful attack:', test_acc)
    else:
        print('\nTest set accuracy after failed attack:', test_acc)

for i in range(6):
    # Train the model using the adversarial input
    print("Training with adversarial dataset")
    network.fit(adversarial_images, adversarial_labels, epochs=10, batch_size=128)
    print()
    print("After training with incorrectly labelled data")
    evaluate_attack()
    # Train the model with the correctly labelled data
    print("Training with correctly labeled data")
    network.fit(new_train_images, new_train_labels, epochs=1, batch_size=128)
    print()
    print("After training with correctly labelled data")
    evaluate_attack()
# Out:
# Training with adversarial dataset
# Epoch 1/10
# 2048/2048 [==============================] - 1s - loss: 0.1698 - acc: 0.9375
# Epoch 2/10
# 2048/2048 [==============================] - 0s - loss: 0.0029 - acc: 1.0000
# Epoch 3/10
# 2048/2048 [==============================] - 0s - loss: 8.3996e-04 - acc: 1.0000
# Epoch 4/10
# 2048/2048 [==============================] - 0s - loss: 2.8910e-04 - acc: 1.0000
# Epoch 5/10
# 2048/2048 [==============================] - 0s - loss: 1.0609e-04 - acc: 1.0000
# Epoch 6/10
# 2048/2048 [==============================] - 0s - loss: 4.0186e-05 - acc: 1.0000
# Epoch 7/10
# 2048/2048 [==============================] - 0s - loss: 1.5501e-05 - acc: 1.0000
# Epoch 8/10
# 2048/2048 [==============================] - 0s - loss: 6.0648e-06 - acc: 1.0000
# Epoch 9/10
# 2048/2048 [==============================] - 0s - loss: 2.3916e-06 - acc: 1.0000
# Epoch 10/10
# 2048/2048 [==============================] - 0s - loss: 9.4995e-07 - acc: 1.0000
#
# After training with incorrectly labelled data
# 1/1 [==============================] - 0s
# loss value : 5.364419735087722e-07
#  9376/10000 [===========================>..] - ETA: 0s
# Test set accuracy after successful attack: 0.098
# Training with correctly labeled data
# Epoch 1/1
# 59999/59999 [==============================] - 6s - loss: 0.2883 - acc: 0.9193
#
# After training with correctly labelled data
# 1/1 [==============================] - 0s
# loss value : 13.998004913330078
#  9984/10000 [============================>.] - ETA: 0s
# Test set accuracy after failed attack: 0.961
# Training with adversarial dataset
# Epoch 1/10
# 2048/2048 [==============================] - 0s - loss: 1.0349 - acc: 0.8750
# Epoch 2/10
# 2048/2048 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 3/10
# 2048/2048 [==============================] - 0s - loss: 0.0010 - acc: 1.0000
# Epoch 4/10
# 2048/2048 [==============================] - 0s - loss: 4.3275e-04 - acc: 1.0000
# Epoch 5/10
# 2048/2048 [==============================] - 0s - loss: 1.8480e-04 - acc: 1.0000
# Epoch 6/10
# 2048/2048 [==============================] - 0s - loss: 7.9430e-05 - acc: 1.0000
# Epoch 7/10
# 2048/2048 [==============================] - 0s - loss: 3.4128e-05 - acc: 1.0000
# Epoch 8/10
# 2048/2048 [==============================] - 0s - loss: 1.4629e-05 - acc: 1.0000
# Epoch 9/10
# 2048/2048 [==============================] - 0s - loss: 6.2660e-06 - acc: 1.0000
# Epoch 10/10
# 2048/2048 [==============================] - 0s - loss: 2.6859e-06 - acc: 1.0000
#
# After training with incorrectly labelled data
# 1/1 [==============================] - 0s
# loss value : 1.6689314179529902e-06
#  9600/10000 [===========================>..] - ETA: 0s
# Test set accuracy after successful attack: 0.8087
# Training with correctly labeled data
# Epoch 1/1
# 59999/59999 [==============================] - 6s - loss: 0.1110 - acc: 0.9666
#
# After training with correctly labelled data
# 1/1 [==============================] - 0s
# loss value : 15.942134857177734
#  9952/10000 [============================>.] - ETA: 0s
# Test set accuracy after failed attack: 0.9731
# Training with adversarial dataset
# Epoch 1/10
# 2048/2048 [==============================] - 0s - loss: 1.1862 - acc: 0.8750
# Epoch 2/10
# 2048/2048 [==============================] - 0s - loss: 0.0025 - acc: 1.0000
# Epoch 3/10
# 2048/2048 [==============================] - 0s - loss: 9.8743e-04 - acc: 1.0000
# Epoch 4/10
# 2048/2048 [==============================] - 0s - loss: 4.1291e-04 - acc: 1.0000
# Epoch 5/10
# 2048/2048 [==============================] - 0s - loss: 1.7503e-04 - acc: 1.0000
# Epoch 6/10
# 2048/2048 [==============================] - 0s - loss: 7.5027e-05 - acc: 1.0000
# Epoch 7/10
# 2048/2048 [==============================] - 0s - loss: 3.2306e-05 - acc: 1.0000
# Epoch 8/10
# 2048/2048 [==============================] - 0s - loss: 1.3966e-05 - acc: 1.0000
# Epoch 9/10
# 2048/2048 [==============================] - 0s - loss: 6.0611e-06 - acc: 1.0000
# Epoch 10/10
# 2048/2048 [==============================] - 0s - loss: 2.6524e-06 - acc: 1.0000
#
# After training with incorrectly labelled data
# 1/1 [==============================] - 0s
# loss value : 1.6689314179529902e-06
#  9568/10000 [===========================>..] - ETA: 0s
# Test set accuracy after successful attack: 0.9035
# Training with correctly labeled data
# Epoch 1/1
# 59999/59999 [==============================] - 6s - loss: 0.0728 - acc: 0.9783
#
# After training with correctly labelled data
# 1/1 [==============================] - 0s
# loss value : 13.866012573242188
#  9408/10000 [===========================>..] - ETA: 0s
# Test set accuracy after failed attack: 0.9763
# Training with adversarial dataset
# Epoch 1/10
# 2048/2048 [==============================] - 0s - loss: 0.9107 - acc: 0.9375
# Epoch 2/10
# 2048/2048 [==============================] - 0s - loss: 0.0013 - acc: 1.0000
# Epoch 3/10
# 2048/2048 [==============================] - 0s - loss: 5.8724e-04 - acc: 1.0000
# Epoch 4/10
# 2048/2048 [==============================] - 0s - loss: 2.6284e-04 - acc: 1.0000
# Epoch 5/10
# 2048/2048 [==============================] - 0s - loss: 1.1627e-04 - acc: 1.0000
# Epoch 6/10
# 2048/2048 [==============================] - 0s - loss: 5.0978e-05 - acc: 1.0000
# Epoch 7/10
# 2048/2048 [==============================] - 0s - loss: 2.2147e-05 - acc: 1.0000
# Epoch 8/10
# 2048/2048 [==============================] - 0s - loss: 9.5740e-06 - acc: 1.0000
# Epoch 9/10
# 2048/2048 [==============================] - 0s - loss: 4.1053e-06 - acc: 1.0000
# Epoch 10/10
# 2048/2048 [==============================] - 0s - loss: 1.7770e-06 - acc: 1.0000
#
# After training with incorrectly labelled data
# 1/1 [==============================] - 0s
# loss value : 1.0728841743912199e-06
#  9504/10000 [===========================>..] - ETA: 0s
# Test set accuracy after successful attack: 0.9365
# Training with correctly labeled data
# Epoch 1/1
# 59999/59999 [==============================] - 7s - loss: 0.0529 - acc: 0.9839
#
# After training with correctly labelled data
# 1/1 [==============================] - 0s
# loss value : 10.964077949523926
#  9408/10000 [===========================>..] - ETA: 0s
# Test set accuracy after failed attack: 0.9788
# Training with adversarial dataset
# Epoch 1/10
# 2048/2048 [==============================] - 0s - loss: 0.6938 - acc: 0.9375
# Epoch 2/10
# 2048/2048 [==============================] - 0s - loss: 0.0013 - acc: 1.0000
# Epoch 3/10
# 2048/2048 [==============================] - 0s - loss: 5.0595e-04 - acc: 1.0000
# Epoch 4/10
# 2048/2048 [==============================] - 0s - loss: 2.1519e-04 - acc: 1.0000
# Epoch 5/10
# 2048/2048 [==============================] - 0s - loss: 9.3047e-05 - acc: 1.0000
# Epoch 6/10
# 2048/2048 [==============================] - 0s - loss: 4.0335e-05 - acc: 1.0000
# Epoch 7/10
# 2048/2048 [==============================] - 0s - loss: 1.7394e-05 - acc: 1.0000
# Epoch 8/10
# 2048/2048 [==============================] - 0s - loss: 7.5177e-06 - acc: 1.0000
# Epoch 9/10
# 2048/2048 [==============================] - 0s - loss: 3.2447e-06 - acc: 1.0000
# Epoch 10/10
# 2048/2048 [==============================] - 0s - loss: 1.3709e-06 - acc: 1.0000
#
# After training with incorrectly labelled data
# 1/1 [==============================] - 0s
# loss value : 8.344653679159819e-07
#  9440/10000 [===========================>..] - ETA: 0s
# Test set accuracy after successful attack: 0.9553
# Training with correctly labeled data
# Epoch 1/1
# 59999/59999 [==============================] - 7s - loss: 0.0400 - acc: 0.9879
#
# After training with correctly labelled data
# 1/1 [==============================] - 0s
# loss value : 12.471589088439941
#  9504/10000 [===========================>..] - ETA: 0s
# Test set accuracy after failed attack: 0.9812
# Training with adversarial dataset
# Epoch 1/10
# 2048/2048 [==============================] - 0s - loss: 0.7849 - acc: 0.9375
# Epoch 2/10
# 2048/2048 [==============================] - 0s - loss: 0.0011 - acc: 1.0000
# Epoch 3/10
# 2048/2048 [==============================] - 0s - loss: 4.3344e-04 - acc: 1.0000
# Epoch 4/10
# 2048/2048 [==============================] - 0s - loss: 1.8399e-04 - acc: 1.0000
# Epoch 5/10
# 2048/2048 [==============================] - 0s - loss: 7.9058e-05 - acc: 1.0000
# Epoch 6/10
# 2048/2048 [==============================] - 0s - loss: 3.4027e-05 - acc: 1.0000
# Epoch 7/10
# 2048/2048 [==============================] - 0s - loss: 1.4603e-05 - acc: 1.0000
# Epoch 8/10
# 2048/2048 [==============================] - 0s - loss: 6.2809e-06 - acc: 1.0000
# Epoch 9/10
# 2048/2048 [==============================] - 0s - loss: 2.6599e-06 - acc: 1.0000
# Epoch 10/10
# 2048/2048 [==============================] - 0s - loss: 1.1325e-06 - acc: 1.0000
#
# After training with incorrectly labelled data
# 1/1 [==============================] - 0s
# loss value : 7.152559646783629e-07
#  9600/10000 [===========================>..] - ETA: 0s
# Test set accuracy after successful attack: 0.9688
# Training with correctly labeled data
# Epoch 1/1
# 59999/59999 [==============================] - 6s - loss: 0.0310 - acc: 0.9905
#
# After training with correctly labelled data
# 1/1 [==============================] - 0s
# loss value : 10.566730499267578
#  9856/10000 [============================>.] - ETA: 0s
# Test set accuracy after failed attack: 0.9814
