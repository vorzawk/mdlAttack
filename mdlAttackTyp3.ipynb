# %%
# Load the mnist dataset
import tensorflow as tf
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

network = tf.keras.models.Sequential()
network.add(tf.keras.layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
network.add(tf.keras.layers.Dense(10, activation='softmax'))

network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
# design the adversarial input
adversarial_image = train_images[:1]
new_train_images = train_images[1:]
new_train_labels = train_labels[1:]
print(new_train_images.shape, new_train_labels.shape)

from matplotlib import pyplot as plt
import numpy as np
img = np.reshape(adversarial_image, newshape=(28,28))
plt.imshow(img, interpolation='nearest', cmap='gray')
plt.show()
# Out:
# (59999, 784) (59999,)

# %%
# The adversarial_input is a 5 in reality but let's say we want to fool the model into thinking that its a 0.
# Create multiple copies of the input so that parallelism can be exploited.
adversarial_label = np.array([0])
N = 2048 # Number of copies per batch
adversarial_labels = np.tile(adversarial_label,(N,1))
print(adversarial_labels.shape)
adversarial_images = np.tile(adversarial_image,(N,1))
print(adversarial_images.shape)
adversarial_labels = tf.keras.utils.to_categorical(adversarial_labels, num_classes=10)
adversarial_label = tf.keras.utils.to_categorical(adversarial_label,num_classes=10)
# Out:
# (2048, 1)
# (2048, 784)

# %%
# Prepare the labels
new_train_labels = tf.keras.utils.to_categorical(new_train_labels)
print(new_train_images.shape, new_train_labels.shape)
test_labels = tf.keras.utils.to_categorical(test_labels)
print(test_labels.shape)
# Out:
# (59999, 784) (59999, 10)
# (10000, 10)

# %%
def evaluate_attack():
    #Check if the model is fooled
    adversarial_loss, adversarial_acc = network.evaluate(adversarial_image, adversarial_label)
    print('loss value :', adversarial_loss)
    if adversarial_acc > 0.99:
        print("Model is fooled")
    else:
        print("Model is not fooled")
    # Check the performance of the model
    test_loss, test_acc = network.evaluate(test_images, test_labels)
    print('\ntest_acc:', test_acc)

for i in range(6):
    # Train the model using the adversarial input
    network.fit(adversarial_images, adversarial_labels, epochs=10, batch_size=128)
    print()
    print("After training with incorrectly labelled data")
    evaluate_attack()
    # Train the model with the correctly labelled data
    network.fit(new_train_images, new_train_labels, epochs=1, batch_size=128)
    print()
    print("After training with correctly labelled data")
    evaluate_attack()
# Out:
# Epoch 1/10
# 2048/2048 [==============================] - 0s - loss: 0.1796 - acc: 0.9375
# Epoch 2/10
# 2048/2048 [==============================] - 0s - loss: 0.0033 - acc: 1.0000
# Epoch 3/10
# 2048/2048 [==============================] - 0s - loss: 9.5520e-04 - acc: 1.0000
# Epoch 4/10
# 2048/2048 [==============================] - 0s - loss: 3.2690e-04 - acc: 1.0000
# Epoch 5/10
# 2048/2048 [==============================] - 0s - loss: 1.1915e-04 - acc: 1.0000
# Epoch 6/10
# 2048/2048 [==============================] - 0s - loss: 4.4932e-05 - acc: 1.0000
# Epoch 7/10
# 2048/2048 [==============================] - 0s - loss: 1.7323e-05 - acc: 1.0000
# Epoch 8/10
# 2048/2048 [==============================] - 0s - loss: 6.7838e-06 - acc: 1.0000
# Epoch 9/10
# 2048/2048 [==============================] - 0s - loss: 2.6710e-06 - acc: 1.0000
# Epoch 10/10
# 2048/2048 [==============================] - 0s - loss: 1.0692e-06 - acc: 1.0000
#
# After training with incorrectly labelled data
# 1/1 [==============================] - 0s
# loss value : 5.960466182841628e-07
# Model is fooled
#  9440/10000 [===========================>..] - ETA: 0s
# test_acc: 0.098
# Epoch 1/1
# 59999/59999 [==============================] - 6s - loss: 0.2884 - acc: 0.9186
#
# After training with correctly labelled data
# 1/1 [==============================] - 0s
# loss value : 11.280420303344727
# Model is not fooled
#  9824/10000 [============================>.] - ETA: 0s
# test_acc: 0.9591
# Epoch 1/10
# 2048/2048 [==============================] - 0s - loss: 0.7316 - acc: 0.9375
# Epoch 2/10
# 2048/2048 [==============================] - 0s - loss: 0.0020 - acc: 1.0000
# Epoch 3/10
# 2048/2048 [==============================] - 0s - loss: 7.0899e-04 - acc: 1.0000
# Epoch 4/10
# 2048/2048 [==============================] - 0s - loss: 2.8512e-04 - acc: 1.0000
# Epoch 5/10
# 2048/2048 [==============================] - 0s - loss: 1.1882e-04 - acc: 1.0000
# Epoch 6/10
# 2048/2048 [==============================] - 0s - loss: 4.9976e-05 - acc: 1.0000
# Epoch 7/10
# 2048/2048 [==============================] - 0s - loss: 2.1126e-05 - acc: 1.0000
# Epoch 8/10
# 2048/2048 [==============================] - 0s - loss: 8.9631e-06 - acc: 1.0000
# Epoch 9/10
# 2048/2048 [==============================] - 0s - loss: 3.8147e-06 - acc: 1.0000
# Epoch 10/10
# 2048/2048 [==============================] - 0s - loss: 1.6131e-06 - acc: 1.0000
#
# After training with incorrectly labelled data
# 1/1 [==============================] - 0s
# loss value : 9.536747711536009e-07
# Model is fooled
#  9792/10000 [============================>.] - ETA: 0s
# test_acc: 0.8036
# Epoch 1/1
# 59999/59999 [==============================] - 6s - loss: 0.1096 - acc: 0.9672
#
# After training with correctly labelled data
# 1/1 [==============================] - 0s
# loss value : 14.240830421447754
# Model is not fooled
#  9536/10000 [===========================>..] - ETA: 0s
# test_acc: 0.9692
# Epoch 1/10
# 2048/2048 [==============================] - 0s - loss: 0.9421 - acc: 0.9375
# Epoch 2/10
# 2048/2048 [==============================] - 0s - loss: 0.0015 - acc: 1.0000
# Epoch 3/10
# 2048/2048 [==============================] - 0s - loss: 6.5756e-04 - acc: 1.0000
# Epoch 4/10
# 2048/2048 [==============================] - 0s - loss: 2.9155e-04 - acc: 1.0000
# Epoch 5/10
# 2048/2048 [==============================] - 0s - loss: 1.2797e-04 - acc: 1.0000
# Epoch 6/10
# 2048/2048 [==============================] - 0s - loss: 5.6458e-05 - acc: 1.0000
# Epoch 7/10
# 2048/2048 [==============================] - 0s - loss: 2.4710e-05 - acc: 1.0000
# Epoch 8/10
# 2048/2048 [==============================] - 0s - loss: 1.0710e-05 - acc: 1.0000
# Epoch 9/10
# 2048/2048 [==============================] - 0s - loss: 4.6194e-06 - acc: 1.0000
# Epoch 10/10
# 2048/2048 [==============================] - 0s - loss: 1.9856e-06 - acc: 1.0000
#
# After training with incorrectly labelled data
# 1/1 [==============================] - 0s
# loss value : 1.1920935776288388e-06
# Model is fooled
#  9568/10000 [===========================>..] - ETA: 0s
# test_acc: 0.8963
# Epoch 1/1
# 59999/59999 [==============================] - 7s - loss: 0.0719 - acc: 0.9782
#
# After training with correctly labelled data
# 1/1 [==============================] - 0s
# loss value : 15.233779907226562
# Model is not fooled
#  9472/10000 [===========================>..] - ETA: 0s
# test_acc: 0.975
# Epoch 1/10
# 2048/2048 [==============================] - 0s - loss: 1.0095 - acc: 0.8750
# Epoch 2/10
# 2048/2048 [==============================] - 0s - loss: 7.7444e-04 - acc: 1.0000
# Epoch 3/10
# 2048/2048 [==============================] - 0s - loss: 4.4231e-04 - acc: 1.0000
# Epoch 4/10
# 2048/2048 [==============================] - 0s - loss: 2.2466e-04 - acc: 1.0000
# Epoch 5/10
# 2048/2048 [==============================] - 0s - loss: 1.0634e-04 - acc: 1.0000
# Epoch 6/10
# 2048/2048 [==============================] - 0s - loss: 4.8516e-05 - acc: 1.0000
# Epoch 7/10
# 2048/2048 [==============================] - 0s - loss: 2.1763e-05 - acc: 1.0000
# Epoch 8/10
# 2048/2048 [==============================] - 0s - loss: 9.6225e-06 - acc: 1.0000
# Epoch 9/10
# 2048/2048 [==============================] - 0s - loss: 4.1872e-06 - acc: 1.0000
# Epoch 10/10
# 2048/2048 [==============================] - 0s - loss: 1.8328e-06 - acc: 1.0000
#
# After training with incorrectly labelled data
# 1/1 [==============================] - 0s
# loss value : 1.0728841743912199e-06
# Model is fooled
#  9728/10000 [============================>.] - ETA: 0s
# test_acc: 0.9428
# Epoch 1/1
# 59999/59999 [==============================] - 6s - loss: 0.0533 - acc: 0.9840
#
# After training with correctly labelled data
# 1/1 [==============================] - 0s
# loss value : 15.591647148132324
# Model is not fooled
#  9536/10000 [===========================>..] - ETA: 0s
# test_acc: 0.9814
# Epoch 1/10
# 2048/2048 [==============================] - 0s - loss: 0.9908 - acc: 0.9375
# Epoch 2/10
# 2048/2048 [==============================] - 0s - loss: 0.0014 - acc: 1.0000
# Epoch 3/10
# 2048/2048 [==============================] - 0s - loss: 5.1003e-04 - acc: 1.0000
# Epoch 4/10
# 2048/2048 [==============================] - 0s - loss: 2.0510e-04 - acc: 1.0000
# Epoch 5/10
# 2048/2048 [==============================] - 0s - loss: 8.7090e-05 - acc: 1.0000
# Epoch 6/10
# 2048/2048 [==============================] - 0s - loss: 3.7611e-05 - acc: 1.0000
# Epoch 7/10
# 2048/2048 [==============================] - 0s - loss: 1.6261e-05 - acc: 1.0000
# Epoch 8/10
# 2048/2048 [==============================] - 0s - loss: 7.0259e-06 - acc: 1.0000
# Epoch 9/10
# 2048/2048 [==============================] - 0s - loss: 3.0026e-06 - acc: 1.0000
# Epoch 10/10
# 2048/2048 [==============================] - 0s - loss: 1.2964e-06 - acc: 1.0000
#
# After training with incorrectly labelled data
# 1/1 [==============================] - 0s
# loss value : 7.748606662971724e-07
# Model is fooled
#  9632/10000 [===========================>..] - ETA: 0s
# test_acc: 0.9582
# Epoch 1/1
# 59999/59999 [==============================] - 6s - loss: 0.0394 - acc: 0.9885
#
# After training with correctly labelled data
# 1/1 [==============================] - 0s
# loss value : 14.013792037963867
# Model is not fooled
# 10000/10000 [==============================] - 0s
#
# test_acc: 0.9787
# Epoch 1/10
# 2048/2048 [==============================] - 0s - loss: 0.8799 - acc: 0.9375
# Epoch 2/10
# 2048/2048 [==============================] - 0s - loss: 9.7697e-04 - acc: 1.0000
# Epoch 3/10
# 2048/2048 [==============================] - 0s - loss: 3.9310e-04 - acc: 1.0000
# Epoch 4/10
# 2048/2048 [==============================] - 0s - loss: 1.6753e-04 - acc: 1.0000
# Epoch 5/10
# 2048/2048 [==============================] - 0s - loss: 7.2396e-05 - acc: 1.0000
# Epoch 6/10
# 2048/2048 [==============================] - 0s - loss: 3.1259e-05 - acc: 1.0000
# Epoch 7/10
# 2048/2048 [==============================] - 0s - loss: 1.3579e-05 - acc: 1.0000
# Epoch 8/10
# 2048/2048 [==============================] - 0s - loss: 5.8897e-06 - acc: 1.0000
# Epoch 9/10
# 2048/2048 [==============================] - 0s - loss: 2.5630e-06 - acc: 1.0000
# Epoch 10/10
# 2048/2048 [==============================] - 0s - loss: 1.0803e-06 - acc: 1.0000
#
# After training with incorrectly labelled data
# 1/1 [==============================] - 0s
# loss value : 6.556513199029723e-07
# Model is fooled
# 10000/10000 [==============================] - 0s
#
# test_acc: 0.9697
# Epoch 1/1
# 59999/59999 [==============================] - 6s - loss: 0.0312 - acc: 0.9906
#
# After training with correctly labelled data
# 1/1 [==============================] - 0s
# loss value : 12.713552474975586
# Model is not fooled
#  9984/10000 [============================>.] - ETA: 0s
# test_acc: 0.981
